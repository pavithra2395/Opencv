# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("../.")

# %%
# !pip install opencv-python
# !pip install matplotlib

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

file_path = '/home/ppavithra/Desktop/notebook/Opencv-main/page1.png'

print(file_path)

input_image = cv2.imread(file_path)
print(input_image)
plt.figure(figsize=(15, 20))
plt.axis('off')
plt.imshow(input_image)
plt.show()
# Out:
# /home/ppavithra/Desktop/notebook/Opencv-main/page1.png
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
# !pip install boxdetect

# %%
from boxdetect import config

cfg = config.PipelinesConfig()

cfg.width_range = (20, 30)
cfg.height_range = (20, 35)
cfg.scaling_factors = [1.9]

cfg.wh_ratio_range = (0.5, 1.7)

cfg.group_size_range = (1, 250)

cfg.morph_kernels_type = 'rectangles'

cfg.dilation_iterations = 2

# %%
# from boxdetect.pipelines import get_checkboxes
from boxdetect.pipelines import get_boxes

rects, grouping_rects, image, output_image = get_boxes(file_path, cfg=cfg, plot=False)
# Out:
# Processing file:  /home/ppavithra/Desktop/notebook/Opencv-main/page1.png

# %%
grouping_rects
# Out:
# [(1080, 260, 25, 25),
#  (1193, 260, 23, 25),
#  (1305, 260, 25, 25),
#  (1418, 260, 24, 25),
#  (1080, 306, 25, 24),
#  (1193, 306, 23, 24),
#  (1418, 306, 24, 24),
#  (1530, 306, 25, 24),
#  (1080, 352, 25, 24),
#  (1305, 352, 25, 24),
#  (1418, 352, 24, 24),
#  (1530, 352, 25, 24),
#  (1080, 408, 25, 25),
#  (1193, 408, 23, 25),
#  (1305, 408, 25, 25),
#  (1530, 408, 25, 25),
#  (1080, 477, 25, 25),
#  (1305, 477, 25, 25),
#  (1418, 477, 24, 25),
#  (1530, 477, 25, 25),
#  (1080, 546, 24, 25),
#  (1193, 546, 23, 25),
#  (1418, 546, 24, 25),
#  (1530, 546, 25, 25),
#  (1080, 615, 25, 26),
#  (1193, 615, 23, 26),
#  (1305, 615, 25, 26),
#  (1418, 615, 24, 26),
#  (1193, 673, 23, 24),
#  (1305, 673, 25, 24),
#  (1418, 673, 24, 24),
#  (1530, 673, 25, 24),
#  (1080, 867, 25, 25),
#  (1193, 867, 23, 25),
#  (1305, 867, 25, 25),
#  (1530, 867, 25, 25),
#  (1080, 916, 25, 25),
#  (1193, 916, 23, 25),
#  (1418, 916, 24, 25),
#  (1530, 916, 25, 25),
#  (1080, 964, 25, 24),
# ...

# %%
rects
# Out:
# array([[1418, 1721,   23,   23],
#        [1305, 1721,   24,   23],
#        [1193, 1721,   22,   23],
#        [1080, 1721,   24,   23],
#        [1530, 1676,   24,   24],
#        [1305, 1676,   24,   24],
#        [1193, 1676,   22,   24],
#        [1080, 1676,   24,   24],
#        [1530, 1631,   24,   22],
#        [1418, 1631,   23,   22],
#        [1305, 1631,   24,   22],
#        [1080, 1631,   24,   22],
#        [1530, 1585,   24,   24],
#        [1418, 1585,   23,   24],
#        [1193, 1585,   22,   24],
#        [1080, 1585,   24,   24],
#        [1530, 1540,   24,   23],
#        [1305, 1540,   24,   23],
#        [1193, 1540,   22,   23],
#        [1080, 1540,   24,   23],
#        [1530, 1495,   24,   24],
#        [1418, 1495,   23,   24],
#        [1193, 1495,   22,   24],
#        [1080, 1495,   24,   24],
#        [1530, 1450,   24,   22],
#        [1418, 1450,   23,   22],
#        [1305, 1450,   24,   22],
#        [1080, 1450,   24,   22],
# ...

# %%
from boxdetect.img_proc import draw_rects, get_image
import matplotlib.pyplot as plt
# %matplotlib inline

out_img = draw_rects(get_image(file_path), rects, thickness=4)

plt.figure(figsize=(15,20))
plt.imshow(out_img)
plt.show()
# Out:
# Processing file:  /home/ppavithra/Desktop/notebook/Opencv-main/page1.png

# %%
import cv2

org_img = cv2.imread(file_path)

for rect in grouping_rects:
    x1 = rect[0]
    x2 = x1 + rect[2]
    y1 = rect[1]
    y2 = y1 + rect[3]
    plt.figure(figsize=(10,1))
    plt.imshow(org_img[y1:y2, x1:x2])
    plt.show()

# %%
from boxdetect.pipelines import get_checkboxes

file_path = '/home/ppavithra/Desktop/notebook/Opencv-main/page1.png'

checkboxes = get_checkboxes(file_path, cfg=cfg, px_threshold=0.1, plot=False, verbose=True)
# Out:
# Processing file:  /home/ppavithra/Desktop/notebook/Opencv-main/page1.png
# ----------------------------------
# nonzero_px_count:  0
# all_px_count:  361
# nonzero_px_count / all_px_count =  0.0
# ----------------------------------
# ----------------------------------
# nonzero_px_count:  0
# all_px_count:  323
# nonzero_px_count / all_px_count =  0.0
# ----------------------------------
# ----------------------------------
# nonzero_px_count:  0
# all_px_count:  361
# nonzero_px_count / all_px_count =  0.0
# ----------------------------------
# ----------------------------------
# nonzero_px_count:  0
# all_px_count:  342
# nonzero_px_count / all_px_count =  0.0
# ----------------------------------
# ----------------------------------
# nonzero_px_count:  0
# all_px_count:  342
# nonzero_px_count / all_px_count =  0.0
# ----------------------------------
# ----------------------------------
# nonzero_px_count:  0
# all_px_count:  306
# nonzero_px_count / all_px_count =  0.0
# ...

# %%
print("Output object type: ", type(checkboxes))
for checkbox in checkboxes:
    print("Checkbox bounding rectangle (x,y,width,height): ", checkbox[0])
    print("Result of `contains_pixels` for the checkbox: ", checkbox[1])
    print("Display the cropout of checkbox:")
    plt.figure(figsize=(1,1))
    plt.imshow(checkbox[2])
    plt.show()
# Out:
# Output object type:  <class 'numpy.ndarray'>
# Checkbox bounding rectangle (x,y,width,height):  (1080, 260, 25, 25)
# Result of `contains_pixels` for the checkbox:  False
# Display the cropout of checkbox:
# Checkbox bounding rectangle (x,y,width,height):  (1193, 260, 23, 25)
# Result of `contains_pixels` for the checkbox:  False
# Display the cropout of checkbox:
# Checkbox bounding rectangle (x,y,width,height):  (1305, 260, 25, 25)
# Result of `contains_pixels` for the checkbox:  False
# Display the cropout of checkbox:
# Checkbox bounding rectangle (x,y,width,height):  (1418, 260, 24, 25)
# Result of `contains_pixels` for the checkbox:  False
# Display the cropout of checkbox:
# Checkbox bounding rectangle (x,y,width,height):  (1080, 306, 25, 24)
# Result of `contains_pixels` for the checkbox:  False
# Display the cropout of checkbox:
# Checkbox bounding rectangle (x,y,width,height):  (1193, 306, 23, 24)
# Result of `contains_pixels` for the checkbox:  False
# ...
